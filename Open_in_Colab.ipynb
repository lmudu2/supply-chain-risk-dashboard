# %% [markdown]
# # Supply Chain Risk Dashboard in Google Colab
# ## Instructions
# 1. **Run all cells** to set up the environment and start the application.
# 2. When the `npx localtunnel` cell runs, it will print a link and ask for an IP address as a password.
# 3. Copy the IP address printed by the previous cell and paste it into the localtunnel password prompt.
# 4. Click the localtunnel url to launch the app!

# %%
# !git clone https://github.com/lmudu2/supply-chain-risk-dashboard.git
# %cd supply-chain-risk-dashboard
# %pip install -r requirements.txt
# !npm install localtunnel

# %%
import urllib
print("Password/Enpoint IP for localtunnel is:", urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip("\n"))

# %%
# !streamlit run app.py &>/content/logs.txt &
# !npx localtunnel --port 8501
